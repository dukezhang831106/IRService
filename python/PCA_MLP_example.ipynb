# %% [markdown]
# # Motivation
#
# Describe shock scenarios on yield curve.
#
# ## Methodologies
#
# 1. PCA (Widely used in industry)
# 2. MLP (Proof of Concept)
#
# ## Application
#
# 1. Risk exposure due to yield curve shifting
# 2. Prediction of yield curve term structure
# 3. Build stressed scenarios

# %%
import pandas as pd
from MLPRegressor import *

data = pd.read_csv('USDSwap.csv')
curve = CurveDynamics(data)
# Out:
# Using TensorFlow backend.

# %%
curve.plot_raw_data()

# %% [markdown]
# # Task: PCA Decomposition of Yield Curve

# %%
curve.PCARegressor()

# %% [markdown]
# # Task: Low Dimensional Representation

# %%
curve.AutoEncoder()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0723 19:08:12.713533 4611384768 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0723 19:08:12.725107 4611384768 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0723 19:08:12.728905 4611384768 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# /Users/tianyizhang/Projects/IRService/MLPRegressor.py:179: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   self.autoencoder = Model(input=data, output=output)
# ...

# %%
print(curve.data.iloc[700])
curve.lowDimensionRepresentation(700)
# Out:
# 1Y     1.416
# 2Y     1.555
# 3Y     1.669
# 4Y     1.763
# 5Y     1.845
# 6Y     1.919
# 7Y     1.986
# 8Y     2.046
# 9Y     2.100
# 10Y    2.149
# 15Y    2.310
# 20Y    2.386
# 30Y    2.423
# Name: 2017-06-20, dtype: float64

# %%
print(curve.data.iloc[800])
curve.lowDimensionRepresentation(800)
# Out:
# 1Y     1.696
# 2Y     1.872
# 3Y     1.981
# 4Y     2.059
# 5Y     2.122
# 6Y     2.182
# 7Y     2.238
# 8Y     2.288
# 9Y     2.333
# 10Y    2.373
# 15Y    2.512
# 20Y    2.579
# 30Y    2.609
# Name: 2017-11-13, dtype: float64

# %%
print(curve.data.iloc[900])
curve.lowDimensionRepresentation(900)
# Out:
# 1Y     1.943
# 2Y     1.714
# 3Y     1.655
# 4Y     1.658
# 5Y     1.687
# 6Y     1.729
# 7Y     1.775
# 8Y     1.820
# 9Y     1.866
# 10Y    1.909
# 15Y    2.062
# 20Y    2.133
# 30Y    2.174
# Name: 2019-06-25, dtype: float64

# %% [markdown]
# # Task: Generate shocked scenarios

# %%
curve.PCAShock(cnt=100)

# %%
curve.PCAShock(cnt=500)

# %% [markdown]
# # Task: Describe Yield Curve Co-Movement (To-Do)
